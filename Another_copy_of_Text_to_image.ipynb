# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramanarayanan/DeepLearningAndGenerativeAi/blob/main/Another_copy_of_Text_to_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qq -U diffusers transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 29.0 MB/s eta 0:00:00

# %%
from diffusers import StableDiffusionLDM3DPipeline

pipe = StableDiffusionLDM3DPipeline.from_pretrained("Intel/ldm3d-4c")

# On CPU
#pipe.to("cpu")

# On GPU
pipe.to("cuda")

prompt ="T rex dinosour in jurassic park"
name = "lion"

output = pipe(prompt)
# Out:
# ...
#   0%|          | 0/49 [00:00<?, ?it/s]

# %%
rgb_image, depth_image = output.rgb, output.depth
rgb_image[0].save(name+"_ldm3d_4c_rgb.jpg")
depth_image[0].save(name+"_ldm3d_4c_depth.png")

# %%
from IPython.display import Image, display

# %%
# Path to the image file
image_path = "/content/"+name+"_ldm3d_4c_rgb.jpg"

# Display the image
display(Image(filename=image_path))

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('/content/'+name+"_ldm3d_4c_rgb.jpg")
imgplot = plt.imshow(img)
plt.show()
